# %% [markdown]
# <a href="https://colab.research.google.com/github/omelikechi/ipss/blob/main/simple_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A simple example using integrated path stability selection (IPSS)

# %% [markdown]
# ## Install ipss and import libraries

# %%
# %pip install --upgrade --no-cache-dir ipss

from ipss import ipss
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: ipss in /usr/local/lib/python3.11/dist-packages (1.0.16)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from ipss) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from ipss) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ipss) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from ipss) (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from ipss) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ipss) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->ipss) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->ipss) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->ipss) (2.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->ipss) (1.17.0)

# %% [markdown]
# ## Generate data
# 1. Generate coefficient vector $\beta$ with `n_true` randomly located nonzero entries
# 2. Draw `n` samples of `p`-dimensional features from the standard normal distribution
# 3. Generate continuous response `y` according to specified signal-to-noise ratio, `snr`

# %%
# set random seed
np.random.seed(1)

n = 250 # number of samples
p = 500 # number of features
n_true = 10 # number of true features
snr = 2 # signal-to-noise ratio

# generate features
X = np.random.normal(0, 1, size=(n,p))

# randomly select true features
true_features = np.random.choice(p, size=n_true, replace=False)

# generate response
beta = np.zeros(p)
beta[true_features] = np.random.normal(0, 1, size=(n_true))
signal = X @ beta
noise = np.sqrt(np.var(signal) / snr)
y = signal + np.random.normal(0, noise, size=n)

# function for counting true and false positives
def count_tp_fp(selected_features, true_features):
	tp, fp = 0, 0
	for feature in selected_features:
		if feature in true_features:
			tp += 1
		else:
			fp += 1
	return tp, fp

# %% [markdown]
# ## Run IPSS

# %%
ipss_output = ipss(X, y, selector='l1')

# %% [markdown]
# ## Analyze results

# %%
runtime = ipss_output['runtime']
print(f'Runtime: {np.round(runtime,2)} seconds')
print(f'')

# select features based on target number of false positives
target_fp = 1
efp_scores = ipss_output['efp_scores']
selected_features = [idx for idx, efp_score in efp_scores.items() if efp_score <= target_fp]
tp, fp = count_tp_fp(selected_features, true_features)
print(f'-------- Target E(FP) = {target_fp} --------')
print(f'Selected features: {selected_features}')
print(f'Number of true positives: {tp}')
print(f'Number of false positives: {fp}')
print(f'')

# select features based on target FDR
target_fdr = 0.1
q_values = ipss_output['q_values']
selected_features = [idx for idx, q_value in q_values.items() if q_value <= target_fdr]
tp, fp = count_tp_fp(selected_features, true_features)
print(f'-------- Target FDR = {target_fdr} --------')
print(f'Selected features: {selected_features}')
print(f'Number of true positives: {tp}')
print(f'Number of false positives: {fp}')
print(f'')
# Out:
# Runtime: 0.59 seconds
#
# -------- Target E(FP) = 1 --------
# Selected features: [275, 202, 405, 184, 259]
# Number of true positives: 5
# Number of false positives: 0
#
# -------- Target FDR = 0.1 --------
# Selected features: [275, 202, 405, 184, 259]
# Number of true positives: 5
# Number of false positives: 0

# %% [markdown]
# ## Plot stability paths

# %%
stability_paths = ipss_output['stability_paths']
n_alphas, p = stability_paths.shape

# blue paths for true features, gray for false features
color = ['dodgerblue' if i in true_features else 'gray' for i in range(p)]

for j in range(p):
	plt.plot(np.arange(n_alphas), stability_paths[:,j], color=color[j])
plt.tight_layout()
plt.show()
